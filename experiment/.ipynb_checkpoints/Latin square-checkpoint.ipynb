# %%
import pandas as pd

# %%
df = pd.read_csv("affordance_natural.csv")
df = df[df['prompt_type'] == "implicit"]
df.head(3)
# Out:
#     group_id                                          condition prompt_type  \
# 18         1  Brad was sitting in his office when an intrude...    implicit
# 19         2  Jenny was hiking in the woods. She left her fr...    implicit
# 20         3  Art was having a party. He realized he didn't ...    implicit
#
#    key_verb    afforded_text non-afforded_text   related_text  \
# 18  protect  laptop computer      paper napkin  hunting rifle
# 19    point              pen            nickel         string
# 20  protect     floppy disks           pencils  old magazines
#
#                  afforded_image        non-afforded_image  \
# 18  laptopcomputer_natural.jpeg  papernapkin_natural.jpeg
# 19             pen_natural.jpeg       nickel_natural.jpeg
# 20     floppydisks_natural.jpeg      pencils_natural.jpeg
#
#                 related_image
# 18  huntingrifle_natural.jpeg
# 19        string_natural.jpeg
# 20  oldmagazines_natural.jpeg

# %%
df['scenario'] = df['condition']

# %%
conditions = ['afforded', 'non-afforded', 'related']

# We'll collect rows in a list of dicts, then convert to DataFrame
output_rows = []

# Enumerate each row in the original CSV
for i, row in df.iterrows():
    # i = row index (0-based)
    # row = the actual row data (scenario, afforded_image, ...)

    scenario_id = row['condition'] 

    # For each group (1..3), we rotate conditions in a Latin Square manner
    for group in range(3):
        # condition index: shift by (i + group)
        condition_idx = (i + group) % 3
        condition_name = conditions[condition_idx]

        # figure out which image column to pull
        # e.g., for 'afforded', we look at row['afforded_image']
        if condition_name == 'afforded':
            image_path = row['afforded_image']
        elif condition_name == 'non-afforded':
            image_path = row['non-afforded_image']
        else:
            image_path = row['related_image']

        image_path = "images/" + image_path

        output_rows.append({
            'list_id'  : group + 1,        # groups labeled 1, 2, 3
            'scenario'  : scenario_id,
            'condition' : condition_name.title(),
            'group_id': row['group_id'],
            'image_path': image_path,
            
        })

# Create a new DataFrame
latin_df = pd.DataFrame(output_rows)

# %%
latin_df.groupby("list_id")['condition'].value_counts()
# Out:
# list_id  condition
# 1        Afforded        6
#          Non-Afforded    6
#          Related         6
# 2        Afforded        6
#          Non-Afforded    6
#          Related         6
# 3        Afforded        6
#          Non-Afforded    6
#          Related         6
# Name: count, dtype: int64

# %%
latin_df.head(2)
# Out:
#    list_id                                           scenario     condition  \
# 0        1  Brad was sitting in his office when an intrude...      Afforded
# 1        2  Brad was sitting in his office when an intrude...  Non-Afforded
#
#    group_id                          image_path
# 0         1  images/laptopcomputer_natural.jpeg
# 1         1     images/papernapkin_natural.jpeg

# %%
latin_df
# Out:
#     list_id                                           scenario     condition  \
# 0         1  Brad was sitting in his office when an intrude...      Afforded
# 1         2  Brad was sitting in his office when an intrude...  Non-Afforded
# 2         3  Brad was sitting in his office when an intrude...       Related
# 3         1  Jenny was hiking in the woods. She left her fr...  Non-Afforded
# 4         2  Jenny was hiking in the woods. She left her fr...       Related
# 5         3  Jenny was hiking in the woods. She left her fr...      Afforded
# 6         1  Art was having a party. He realized he didn't ...       Related
# 7         2  Art was having a party. He realized he didn't ...      Afforded
# 8         3  Art was having a party. He realized he didn't ...  Non-Afforded
# 9         1  Mike was freezing in the wind. He needed somet...      Afforded
# 10        2  Mike was freezing in the wind. He needed somet...  Non-Afforded
# ...

# %%
latin_df.to_csv("latin_square_natural.csv", index = False, sep='\t')

# %%
df_long = pd.melt(df[['scenario', 'group_id', 'afforded_image', 'non-afforded_image', 'related_image']],
        id_vars=["scenario", "group_id"],
                  var_name="Condition", value_name="image_path")
df_long['Condition'] = df_long['Condition'].apply(lambda x: x.split("_")[0].title())
df_long['image_path'] = df_long['image_path'].apply(lambda x: "images/" + x)
df_long.head(3)
# Out:
#                                             scenario  group_id Condition  \
# 0  Brad was sitting in his office when an intrude...         1  Afforded
# 1  Jenny was hiking in the woods. She left her fr...         2  Afforded
# 2  Art was having a party. He realized he didn't ...         3  Afforded
#
#                            image_path
# 0  images/laptopcomputer_natural.jpeg
# 1             images/pen_natural.jpeg
# 2     images/floppydisks_natural.jpeg

# %%
df_merged = pd.merge(latin_df, df_long)

# %%
df_merged
# Out:
#     list_id                                           scenario     condition  \
# 0         1  Brad was sitting in his office when an intrude...      Afforded
# 1         2  Brad was sitting in his office when an intrude...  Non-Afforded
# 2         3  Brad was sitting in his office when an intrude...       Related
# 3         1  Jenny was hiking in the woods. She left her fr...  Non-Afforded
# 4         2  Jenny was hiking in the woods. She left her fr...       Related
# 5         3  Jenny was hiking in the woods. She left her fr...      Afforded
# 6         1  Art was having a party. He realized he didn't ...       Related
# 7         2  Art was having a party. He realized he didn't ...      Afforded
# 8         3  Art was having a party. He realized he didn't ...  Non-Afforded
# 9         1  Mike was freezing in the wind. He needed somet...      Afforded
# 10        2  Mike was freezing in the wind. He needed somet...  Non-Afforded
# ...
